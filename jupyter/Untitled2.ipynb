# %%
import bs4
import requests

# %%
soup = bs4.BeautifulSoup

# %%
response = requests.get("https://punchng.com/?s=banditry+and+kidnapping")

# %%
news = soup(response.text).find_all("div", {"class": "entries-grid row"})

# %%
news
# Out:
# [<div class="entries-grid row">
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/terrorism-banditry-kidnapping-others-a-test-of-nations-democracy-defence-minister/">
#  <img alt="Defence Minister" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2020/08/08173636/Defence-Minister.jpg" data-srcset="" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/terrorism-banditry-kidnapping-others-a-test-of-nations-democracy-defence-minister/">Terrorism, banditry, kidnapping, others a test of nation’s democracy — Defence Minister</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/banditry-kidnapping-affecting-learning-teaching-don/">
#  <img alt="Some-of-the-arrested-bandits" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2019/07/23224509/Some-of-the-arrested-bandits.png" data-srcset="" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/banditry-kidnapping-affecting-learning-teaching-don/">Banditry, kidnapping affecting learning, teaching – Don</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/army-begins-three-exercises-to-tackle-kidnapping-banditry/">
#  <img alt="Chief of Army Staff, Lieutenant General Farouk Yahaya" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2021/08/13193613/Chief-of-Army-Staff-Lieutenant-General-Faruk-Yahaya-640x358.jpg" data-srcset="https://cdn.punchng.com/wp-content/uploads/2021/08/13193613/Chief-of-Army-Staff-Lieutenant-General-Faruk-Yahaya-300x168.jpg 300w, https://cdn.punchng.com/wp-content/uploads/2021/08/13193613/Chief-of-Army-Staff-Lieutenant-General-Faruk-Yahaya-640x358.jpg 640w, https://cdn.punchng.com/wp-content/uploads/2021/08/13193613/Chief-of-Army-Staff-Lieutenant-General-Faruk-Yahaya-255x143.jpg 255w, https://cdn.punchng.com/wp-content/uploads/2021/08/13193613/Chief-of-Army-Staff-Lieutenant-General-Faruk-Yahaya.jpg 750w" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/army-begins-three-exercises-to-tackle-kidnapping-banditry/">Army begins three exercises to tackle kidnapping, banditry</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/i-felt-peace-on-arrival-in-us-knowing-there-wont-be-banditry-kidnapping-nworie-first-class-unn-graduate-who-got-phd-scholarship/">
#  <img alt="Nworie Emmanuel" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2021/09/04002620/Nworie-Emmanuel-640x366.jpg" data-srcset="https://cdn.punchng.com/wp-content/uploads/2021/09/04002620/Nworie-Emmanuel-300x171.jpg 300w, https://cdn.punchng.com/wp-content/uploads/2021/09/04002620/Nworie-Emmanuel-640x366.jpg 640w, https://cdn.punchng.com/wp-content/uploads/2021/09/04002620/Nworie-Emmanuel-255x146.jpg 255w, https://cdn.punchng.com/wp-content/uploads/2021/09/04002620/Nworie-Emmanuel-130x74.jpg 130w, https://cdn.punchng.com/wp-content/uploads/2021/09/04002620/Nworie-Emmanuel.jpg 700w" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/i-felt-peace-on-arrival-in-us-knowing-there-wont-be-banditry-kidnapping-nworie-first-class-unn-graduate-who-got-phd-scholarship/">I felt peace on arrival in US, knowing there won’t be banditry, kidnapping – Nworie, first-class UNN graduate who got PhD scholarship</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/enough-of-bloodbath-kidnappings-banditry-clergy-pleads/">
#  <img alt="Rev. Musa Likita" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2021/08/16154754/a1-517x480.jpg" data-srcset="https://cdn.punchng.com/wp-content/uploads/2021/08/16154754/a1-300x279.jpg 300w, https://cdn.punchng.com/wp-content/uploads/2021/08/16154754/a1-768x713.jpg 768w, https://cdn.punchng.com/wp-content/uploads/2021/08/16154754/a1-775x720.jpg 775w, https://cdn.punchng.com/wp-content/uploads/2021/08/16154754/a1-517x480.jpg 517w, https://cdn.punchng.com/wp-content/uploads/2021/08/16154754/a1-255x237.jpg 255w, https://cdn.punchng.com/wp-content/uploads/2021/08/16154754/a1.jpg 923w" sizes="(max-width: 517px) 100vw, 517px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/enough-of-bloodbath-kidnappings-banditry-clergy-pleads/">Enough of bloodbath, kidnappings, banditry, clergy pleads</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/troops-winning-war-against-banditry-kidnapping-in-zamfara-coas/">
#  <img alt="Major-General Farouk Yahaya" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2021/05/27145025/Screenshot-2021-05-27-at-2.49.18-PM-640x410.png" data-srcset="https://cdn.punchng.com/wp-content/uploads/2021/05/27145025/Screenshot-2021-05-27-at-2.49.18-PM-300x192.png 300w, https://cdn.punchng.com/wp-content/uploads/2021/05/27145025/Screenshot-2021-05-27-at-2.49.18-PM-768x493.png 768w, https://cdn.punchng.com/wp-content/uploads/2021/05/27145025/Screenshot-2021-05-27-at-2.49.18-PM-640x410.png 640w, https://cdn.punchng.com/wp-content/uploads/2021/05/27145025/Screenshot-2021-05-27-at-2.49.18-PM-255x164.png 255w, https://cdn.punchng.com/wp-content/uploads/2021/05/27145025/Screenshot-2021-05-27-at-2.49.18-PM.png 842w" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/troops-winning-war-against-banditry-kidnapping-in-zamfara-coas/">Troops winning war against banditry, kidnapping in Zamfara –COAS</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/tackle-kidnapping-banditry-pdp-tells-apc/">
#  <img alt="katsina banditry" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2021/01/25235443/katsina-banditry.jpg" data-srcset="" sizes="(max-width: 610px) 100vw, 610px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/tackle-kidnapping-banditry-pdp-tells-apc/">Tackle kidnapping, banditry, PDP tells APC</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/eid-make-sacrifices-to-end-kidnapping-banditry-bauchi-speaker-tells-nigerians/">
#  <img alt="bauchi state map" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2021/03/06182934/bauchi-state-map.jpg" data-srcset="" sizes="(max-width: 512px) 100vw, 512px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/eid-make-sacrifices-to-end-kidnapping-banditry-bauchi-speaker-tells-nigerians/">Eid: Make sacrifices to end kidnapping, banditry, Bauchi Speaker tells Nigerians</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/weve-reduced-kidnapping-banditry-with-nin-says-pantami/">
#  <img alt="Isa Pantami" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/2021/04/Isa-Pantami.jpg" data-srcset="" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/weve-reduced-kidnapping-banditry-with-nin-says-pantami/">We’ve reduced kidnapping, banditry with NIN, says Pantami</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/eid-buhari-asks-nigerians-to-pray-against-banditry-kidnapping/">
#  <img alt="Buhari" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/2021/04/Buhari.jpg" data-srcset="" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/eid-buhari-asks-nigerians-to-pray-against-banditry-kidnapping/">Eid: Buhari asks Nigerians to pray against banditry, kidnapping</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/buhari-mourns-slain-kaduna-students-vows-to-fight-banditry-kidnapping/">
#  <img alt="Buhari" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/2021/04/Buhari.jpg" data-srcset="" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/buhari-mourns-slain-kaduna-students-vows-to-fight-banditry-kidnapping/">ICYMI: Buhari mourns slain Kaduna students, vows to fight banditry, kidnapping</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/50-armed-herdsmen-arrested-nscdc-alleges-banditry-kidnapping-others/">
#  <img alt="NSCDC" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2016/04/04190817/NSCDC-.jpg" data-srcset="" sizes="(max-width: 500px) 100vw, 500px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/50-armed-herdsmen-arrested-nscdc-alleges-banditry-kidnapping-others/">50 armed herdsmen arrested, NSCDC alleges banditry, kidnapping, others</a></h3>
#  </div>
#  </div>
#  <div class="grid-item-wide">
#  <div class="ad-container">
#  <div class="ad-container-inner">
#  <div class="ad-wrapper">
#  <amp-ad data-enable-refresh="9999999999" data-lazy-fetch="true" data-loading-strategy="2" data-multi-size="320x50,300x250" data-slot="/31989200/dx-png-mobile-1" height="280" type="doubleclick" width="336">
#  <div placeholder=""></div>
#  <div fallback=""></div>
#  </amp-ad>
#  <div class="dx-ad" data-ad="ad_placement_incontent_ad_1" data-render-on="desktop|mobile" id="ad_placement_incontent_ad_1_61dff371d85f6"></div>
#  </div>
#  </div>
#  </div> </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com
jpg" data-srcset="" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/zamfara-assembly-to-make-banditry-kidnapping-capital-offence/">Zamfara Assembly to make banditry, kidnapping capital offence</a></h3>
#  </div>
#  </div>
#  <div class="grid-item">
#  <div class="entry entry-box">
#  <a class="entry-thumbnail-wrapper" href="https://punchng.com/im-working-to-end-banditry-kidnapping-buhari-tells-govs/">
#  <img alt="Items-recovered-from-the-bandits" class="entry-thumbnail img-lazy-load nsp" data-src="https://cdn.punchng.com/wp-content/uploads/2019/05/21233648/Items-recovered-from-the-bandits.jpg" data-srcset="" sizes="(max-width: 640px) 100vw, 640px" src="https://cdn.punchng.com/wp-content/uploads/2021/05/16175056/IMG-20210516-WA0002.jpg"/> </a>
#  <h3 class="entry-title"><a href="https://punchng.com/im-working-to-end-banditry-kidnapping-buhari-tells-govs/">I’m working to end banditry, kidnapping, Buhari tells govs</a></h3>
#  </div>
#  </div>
#  <div class="grid-item-wide">
#  <div class="ad-container">
#  <div class="ad-container-inner">
#  <div class="ad-wrapper">
#  <amp-ad data-enable-refresh="9999999999" data-lazy-fetch="true" data-loading-strategy="2" data-multi-size="320x50,300x250" data-slot="/31989200/dx-png-mobile-1" height="280" type="doubleclick" width="336">
#  <div placeholder=""></div>
#  <div fallback=""></div>
#  </amp-ad>
#  <div class="dx-ad" data-ad="ad_placement_incontent_ad_1" data-render-on="desktop|mobile" id="ad_placement_incontent_ad_1_61dff371e204d"></div>
#  </div>
#  </div>
#  </div> </div>
#  </div>]

# %%
for news in news:
    print(news.text)
# Out:
#
# Terrorism, banditry, kidnapping, others a test of nation’s democracy — Defence Minister
#
#
#
#
#
#
# Banditry, kidnapping affecting learning, teaching – Don
#
#
#
#
#
#
# Army begins three exercises to tackle kidnapping, banditry
#
#
#
#
#
#
# I felt peace on arrival in US, knowing there won’t be banditry, kidnapping – Nworie, first-class UNN graduate who got PhD scholarship
#
#
#
#
#
#
# Enough of bloodbath, kidnappings, banditry, clergy pleads
#
#
#
#
#
#
# Troops winning war against banditry, kidnapping in Zamfara –COAS
#
#
#
#
#
#
# Tackle kidnapping, banditry, PDP tells APC
#
#
#
#
#
#
# Eid: Make sacrifices to end kidnapping, banditry, Bauchi Speaker tells Nigerians
#
#
#
#
#
#
# We’ve reduced kidnapping, banditry with NIN, says Pantami
#
#
#
#
#
#
# Eid: Buhari asks Nigerians to pray against banditry, kidnapping
#
#
#
#
#
#
# ICYMI: Buhari mourns slain Kaduna students, vows to fight banditry, kidnapping
#
#
#
#
#
#
# 50 armed herdsmen arrested, NSCDC alleges banditry, kidnapping, others
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# How those in power are fuelling banditry, kidnapping -Bishop Kukah
#
#
#
#
#
#
# Multi-agency approach needed to combat banditry, kidnapping –NSCDC boss
#
#
#
#
#
#
# Nigerians must join govt against banditry, kidnapping – Jonathan
#
#
#
#
#
#
# Zamfara CP vows to end banditry, kidnapping
#
#
#
#
#
#
# Banditry, kidnapping still big issues in Kaduna –El-Rufai
#
#
#
#
#
#
# Boko Haram crisis fuelling kidnapping, banditry, says Makinde
#
#
#
#
#
#
# Buhari’s status has not helped Katsina to end banditry, kidnapping, killings – Civil society leader
#
#
#
#
#
#
# Buhari orders improved response to kidnapping, banditry
#
#
#
#
#
#
# El-Rufai, lawmakers, monarchs meet over kidnapping, banditry
#
#
#
#
#
#
# El-Rufai, lawmakers, monarchs meet over kidnapping, banditry in Kaduna
#
#
#
#
#
#
# Zamfara Assembly to make banditry, kidnapping capital offence
#
#
#
#
#
#
# I’m working to end banditry, kidnapping, Buhari tells govs
